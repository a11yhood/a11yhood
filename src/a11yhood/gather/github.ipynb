# %% [markdown]
# # gathering metadata on assistive technology
#
# using github graphql api to gather metadata about
# projects tagged with assistive technology.

# %% [markdown]
# this exploration looks specifically at assistive technology tags.
# this might be a good _training_ set for a more open general search
# that tries to differentiate between assistive tech presenting and the real deal.

# %%
    import os, pandas
    from toolz.curried import *
    from pandas import DataFrame, Series, Index
    with __import__("importnb").Notebook():
        from app import App

# %% [markdown]
# The graph QL query is constructed And tuned using the interactive explorer at URL.
# Makes sense to have more queries eventually

# %%
search_blob = """{
      search(query: "%s", type: REPOSITORY, first: 50, after: %s) {
        repositoryCount
    wikiCount
    pageInfo {
      hasNextPage
      endCursor
    }
    edges {
      node {
        ... on Repository {
          url
          id
          stargazerCount
          forkCount
          description
          issues {
            totalCount
          }
          languages(first: 20) {
            nodes {
              name
            }
          }
          licenseInfo {
            name
          }
          fundingLinks {
            platform
            url
          }      
          pullRequests {
            totalCount
          }
          updatedAt
          object(expression: "HEAD:README.md") {
            ... on Blob {
              text
            }
          }
          repositoryTopics(first: 20) {
            edges {
              node {
                topic {
                  name
                }
              }
            }
          }
        }
      }
    }
      }
}"""

# %%
    def get_search_cache(app):
        return app.cache / "github" / "search_responses.pkl"
    @App.impl    
    def set_params(params):
        params.update(Authorization=F"token {os.environ['GITHUB_TOKEN']}")
        
    def get_graphql_client(app):
        from python_graphql_client import GraphqlClient
        return GraphqlClient(
            "https://api.github.com/graphql", app.params
        )

# %%
    async def search_one(query, app, options, after=None):
        get_search_cache(app).parent.mkdir(exist_ok=True, parents=True)
        client = get_graphql_client(app)
        with __import__("shelve").open(get_search_cache(app)) as cache:
            id = F"{query}-{after}"
            cache[id] = await client.execute_async(
                search_blob % (query, str(after and F'"{after}"' or "null")))
            return cache[id]

# %%
    async def search(query, app, options, stop=20):       
        queries = [await search_one(query, app, options)]
        ct = 0
        print(queries[-1])
        while queries[-1]["data"]["search"]:
            if info := queries[-1]["data"]["search"].get("pageInfo"):
                if info["hasNextPage"]:
                    if app.verbosity:
                        print(queries[-1]["data"]["search"]["pageInfo"]["endCursor"])
                    queries.append(
                        await search_one(query, app, options, queries[-1]["data"]["search"]["pageInfo"]["endCursor"])
                    )
                    if app.verbosity:
                        print(F"done {ct}")
                    ct += 1
                    if ct == stop: break
                    continue
            break
        return queries

# %%
@App.impl
async def get_responses(options, app):
    from asyncio import gather
    return await gather(
        search("topic:assistive-technology", app, options, os.environ.get("PAGES", 1)),
        search("topic:screen-reader", app, options, os.environ.get("PAGES", 1))
    )

# %%
@App.impl
def get_frames(app):
    with __import__("shelve").open(get_search_cache(app)) as db:
        data = DataFrame(db.values(), db)["data"].apply(Series
        )["search"].apply(Series
        )["edges"].explode(
        ).apply(Series)["node"].apply(Series).set_index("id")
    data.pullRequests = data.pullRequests.apply(operator.itemgetter("totalCount"))
    data.issues = data.issues.apply(operator.itemgetter("totalCount"))
    data["README"] = data.pop("object").apply(lambda x: x and operator.itemgetter("text")(x) or "")

    data = data.join(
        data.pop("repositoryTopics").apply(Series)["edges"]
        .explode().apply(operator.itemgetter("node")).apply(operator.itemgetter("topic")).apply(operator.itemgetter("name"))
        .groupby(level=0).agg(list).rename("topics")
    )
    return data

# %%
if __name__ == "__main__":
    app = App()
    app.main(__import__(__name__), run=0 or locals().get("__file__") is not None)
    df = app.compact()
    display(
        df.T, 
        df.topics.explode().value_counts().to_frame("count").T.style.set_caption(
            "the column titles are the tags of the returned search results and their counts are in the cells below"
        )
    )
# Out:
# id                                                   R_kgDOItjjpA  \
# url                https://github.com/ai-collection/ai-collection
# stargazerCount                                               8280
# forkCount                                                     827
# description     The Generative AI Landscape - A Collection of ...
# issues                                                         59
# languages                                           {'nodes': []}
# licenseInfo                               {'name': 'MIT License'}
# fundingLinks    [{'platform': 'LIBERAPAY', 'url': 'https://lib...
# pullRequests                                                  801
# updatedAt                                    2025-07-18T06:22:55Z
# README          # <img width="20" style="margin-right:6px;" al...
# topics          [artificial-intelligence, collections, ai, ass...
#
# id                               MDEwOlJlcG9zaXRvcnkyMTgzNjE0OA==  \
# url                            https://github.com/OptiKey/OptiKey
# stargazerCount                                               4344
# forkCount                                                     504
# description     OptiKey - Full computer control and speech wit...
# issues                                                        516
# languages       {'nodes': [{'name': 'C#'}, {'name': 'HTML'}, {...
# licenseInfo           {'name': 'GNU General Public License v3.0'}
# fundingLinks    [{'platform': 'GITHUB', 'url': 'https://github...
# pullRequests                                                  415
# updatedAt                                    2025-07-18T06:45:50Z
# README          # OptiKey\n\nOptiKey is an on-screen keyboard ...
# topics          [eye-tracking, eyetracking, eye-tracker, eyes,...
#
# id                               MDEwOlJlcG9zaXRvcnkzNTM1NjE3OA==  \
# url                    https://github.com/brunopulis/awesome-a11y
# stargazerCount                                               1896
# forkCount                                                     144
# description                              A curate list about A11Y
# issues                                                         20
# languages                                           {'nodes': []}
# licenseInfo      {'name': 'Creative Commons Zero v1.0 Universal'}
# fundingLinks    [{'platform': 'GITHUB', 'url': 'https://github...
# pullRequests                                                  161
# updatedAt                                    2025-07-16T02:16:07Z
# README          # Awesome Accessibility\n\n[![Awesome](https:/...
# topics          [accessibility, wai-aria, wcag, a11y, awesome-...
#
# id                               MDEwOlJlcG9zaXRvcnkyMDAyNzUxMjQ=  \
# url                       https://github.com/Stypox/dicio-android
# stargazerCount                                               1011
# forkCount                                                     100
# description                       Dicio assistant app for Android
# issues                                                        208
# languages       {'nodes': [{'name': 'Ruby'}, {'name': 'Shell'}...
# licenseInfo           {'name': 'GNU General Public License v3.0'}
# fundingLinks    [{'platform': 'LIBERAPAY', 'url': 'https://lib...
# pullRequests                                                  106
# updatedAt                                    2025-07-17T11:41:00Z
# README          # Dicio assistant\n\nDicio is a *free and open...
# topics          [assistant, assistive-technology, personal-ass...
#
# id                               MDEwOlJlcG9zaXRvcnk4MTU3NTc1OQ==  \
# url                          https://github.com/cboard-org/cboard
# stargazerCount                                                696
# forkCount                                                     215
# description     Augmentative and Alternative Communication (AA...
# issues                                                        671
# languages       {'nodes': [{'name': 'HTML'}, {'name': 'CSS'}, ...
# licenseInfo           {'name': 'GNU General Public License v3.0'}
# fundingLinks    [{'platform': 'OPEN_COLLECTIVE', 'url': 'https...
# pullRequests                                                 1296
# updatedAt                                    2025-07-18T12:21:41Z
# README          [![Digital public good](https://github.com/cbo...
# topics          [aac, autism, cerebral-palsy, progressive-web-...
#
# id                                                   R_kgDOJb8f4A  \
# url               https://github.com/themanyone/whisper_dictation
# stargazerCount                                                254
# forkCount                                                      32
# description     Private voice keyboard, AI chat, images, webca...
# issues                                                          9
# languages                         {'nodes': [{'name': 'Python'}]}
# licenseInfo           {'name': 'GNU General Public License v2.0'}
# fundingLinks                                                   []
# pullRequests                                                    5
# updatedAt                                    2025-07-16T20:32:17Z
# README          # Whisper Dictation\n\nPrivate voice keyboard,...
# topics          [assistant-chat-bots, assistive-technology, cl...
#
# id                                                   R_kgDOKrDHjA  \
# url                                https://github.com/voqal/voqal
# stargazerCount                                                186
# forkCount                                                      12
# description     Voice native AI agent for the builders of tomo...
# issues                                                          5
# languages       {'nodes': [{'name': 'JavaScript'}, {'name': 'K...
# licenseInfo                        {'name': 'Apache License 2.0'}
# fundingLinks                                                   []
# pullRequests                                                   50
# updatedAt                                    2025-07-13T00:03:36Z
# README          <img src='.github/media/logo-horizontal-text.s...
# topics          [voice-assistant, voice-recognition, coding-as...
#
# id                                                   R_kgDOGox2Sw  \
# url                            https://github.com/HARPLab/DReyeVR
# stargazerCount                                                176
# forkCount                                                      50
# description     VR driving 🚙 + eye tracking 👀 simulator based ...
# issues                                                        146
# languages       {'nodes': [{'name': 'C++'}, {'name': 'C#'}, {'...
# licenseInfo                               {'name': 'MIT License'}
# fundingLinks                                                   []
# pullRequests                                                   29
# updatedAt                                    2025-06-13T01:26:01Z
# README          # DReyeVR\n### Welcome to DReyeVR, a VR drivin...
# topics          [carla-simulator, carla, vr, virtual-reality, ...
#
# id                                                   R_kgDOJ4lpzw  \
# url                              https://github.com/tmc/righthand
# stargazerCount                                                113
# forkCount                                                      10
# description            RightHand - A GPT4 powered assistive tool.
# issues                                                          2
# languages                             {'nodes': [{'name': 'Go'}]}
# licenseInfo                                                  None
# fundingLinks                                                   []
# pullRequests                                                    0
# updatedAt                                    2025-07-01T15:23:13Z
# README          # RightHand - Voice Controlled Assistant for M...
# topics          [assistive, assistive-technology, golang, gpt4...
#
# id                               MDEwOlJlcG9zaXRvcnkzNDAwMzA2MzA=  ...  \
# url               https://github.com/pedrooaugusto/speech-to-code  ...
# stargazerCount                                                 86  ...
# forkCount                                                      12  ...
# description     Speech to Code - Enables you to code using jus...  ...
# issues                                                          3  ...
# languages       {'nodes': [{'name': 'TypeScript'}, {'name': 'P...  ...
# licenseInfo           {'name': 'GNU General Public License v3.0'}  ...
# fundingLinks                                                   []  ...
# pullRequests                                                    0  ...
# updatedAt                                    2025-05-30T16:46:40Z  ...
# README          # Speech To Code <img alt="Toolkit audit statu...  ...
# topics          [speech-to-code, automata-theory, voice-recogn...  ...
#
# id                               MDEwOlJlcG9zaXRvcnkzMjg2MjUwMjg=  \
# url             https://github.com/Agathebadia/inclusive-desig...
# stargazerCount                                                  0
# forkCount                                                       0
# description     Implement & Inclusive design, components, for ...
# issues                                                          0
# languages          {'nodes': [{'name': 'CSS'}, {'name': 'HTML'}]}
# licenseInfo                                                  None
# fundingLinks                                                   []
# pullRequests                                                    0
# updatedAt                                    2021-03-05T16:25:35Z
# README
# topics          [a11y, a11y-button, accessibility, inclusive-d...
#
# id                                                   R_kgDONLjnqw  \
# url              https://github.com/ScaerieTale/S3R-Screen-Reader
# stargazerCount                                                  0
# forkCount                                                       0
# description     Super Simple Screen Reader lets you paste any ...
# issues                                                          0
# languages       {'nodes': [{'name': 'CSS'}, {'name': 'HTML'}, ...
# licenseInfo                                                  None
# fundingLinks                                                   []
# pullRequests                                                    0
# updatedAt                                    2024-11-16T04:46:01Z
# README
# topics          [accessibility, screen-reader, text-to-speech,...
#
# id                                                   R_kgDONBSJWg  \
# url             https://github.com/mafSida/green-harvest-team-...
# stargazerCount                                                  0
# forkCount                                                       4
# description     Team project built with HTML, CSS, JS, and Vit...
# issues                                                          0
# languages       {'nodes': [{'name': 'CSS'}, {'name': 'HTML'}, ...
# licenseInfo                                                  None
# fundingLinks                                                   []
# pullRequests                                                   47
# updatedAt                                    2024-10-23T17:45:50Z
# README          # Green Harvest Project\n\nA responsive websit...
# topics          [accessibility, css, git, html5, js, mobile-fi...
#
# id                                                   R_kgDOOWXE9Q  \
# url             https://github.com/emirbaycan/ocr_digital_scre...
# stargazerCount                                                  0
# forkCount                                                       0
# description     OCR tool for extracting numbers from digital s...
# issues                                                          0
# languages                         {'nodes': [{'name': 'Python'}]}
# licenseInfo           {'name': 'GNU General Public License v3.0'}
# fundingLinks                                                   []
# pullRequests                                                    0
# updatedAt                                    2025-05-25T12:22:57Z
# README          # ocr_digital_screen_reader\n\n**ocr_digital_s...
# topics          [ai, automation, computer-vision, crnn, data-c...
#
# id                                                   R_kgDOIzKasg  \
# url             https://github.com/sig-a11y/BaoYi-fake-nvdaCon...
# stargazerCount                                                  0
# forkCount                                                       1
# description     A fake nvdaControllerClient.dll, but take BaoY...
# issues                                                          0
# languages             {'nodes': [{'name': 'C'}, {'name': 'C++'}]}
# licenseInfo                                                  None
# fundingLinks                                                   []
# pullRequests                                                    0
# updatedAt                                    2023-01-25T10:03:39Z
# README          # BaoYi-fake-nvda\n\n> A fake `nvdaControllerC...
# topics          [a11y, accessibility, nvda, screen-reader, win...
#
# id                               MDEwOlJlcG9zaXRvcnkxMDEyMTc2MTQ=  \
# url             https://github.com/hatemile/firefox-hatemile-f...
# stargazerCount                                                  0
# forkCount                                                       1
# description     Improve the accessibility of web pages, especi...
# issues                                                          1
# languages       {'nodes': [{'name': 'JavaScript'}, {'name': 'C...
# licenseInfo                        {'name': 'Apache License 2.0'}
# fundingLinks                                                   []
# pullRequests                                                    0
# updatedAt                                    2023-01-28T19:46:12Z
# README          # firefox-hatemile-for-browser\nImprove the ac...
# topics          [accessibility, assistive-technology, screen-r...
#
# id                               MDEwOlJlcG9zaXRvcnkxOTUxNjA5MA==  \
# url                  https://github.com/hatemile/hatemile-for-php
# stargazerCount                                                  0
# forkCount                                                       1
# description     HaTeMiLe is a library that can convert a HTML ...
# issues                                                          0
# languages       {'nodes': [{'name': 'PHP'}, {'name': 'JavaScri...
# licenseInfo                        {'name': 'Apache License 2.0'}
# fundingLinks                                                   []
# pullRequests                                                    1
# updatedAt                                    2018-10-30T21:08:26Z
# README          HaTeMiLe for PHP\n================\n\nHaTeMiLe...
# topics          [accessibility, assistive-technology, screen-r...
#
# id                                                   R_kgDOONatUQ  \
# url                 https://github.com/code-with-amirhossein/a11y
# stargazerCount                                                  0
# forkCount                                                       0
# description     A short look on accessibility in front-end dev...
# issues                                                          0
# languages       {'nodes': [{'name': 'TypeScript'}, {'name': 'C...
# licenseInfo                                                  None
# fundingLinks                                                   []
# pullRequests                                                   29
# updatedAt                                    2025-05-06T17:26:09Z
# README
# topics             [a11y, accessibility, frontend, screen-reader]
#
# id                                                   R_kgDOHsjedw  \
# url             https://github.com/sophiamersmann/friendly-charts
# stargazerCount                                                  0
# forkCount                                                       0
# description     Screen reader friendly charts with minimal effort
# issues                                                          0
# languages                     {'nodes': [{'name': 'TypeScript'}]}
# licenseInfo                               {'name': 'MIT License'}
# fundingLinks                                                   []
# pullRequests                                                   12
# updatedAt                                    2022-09-04T15:46:59Z
# README          # Friendly Charts\n\nScreen reader friendly ch...
# topics          [a11y, charts, keyboard-accesible, screen-reader]
#
# id                                                   R_kgDOHQTMEg
# url             https://github.com/arunpraba/useAccessibleTime...
# stargazerCount                                                  0
# forkCount                                                       0
# description     useAccessibleScreenReaderTimeCounter is a hook...
# issues                                                          0
# languages       {'nodes': [{'name': 'HTML'}, {'name': 'JavaScr...
# licenseInfo                                                  None
# fundingLinks                                                   []
# pullRequests                                                    0
# updatedAt                                    2023-07-22T03:24:45Z
# README          # useAccessibleScreenReaderTimeCounter\n`useAc...
# topics                [react, screen-reader, screen-reader-timer]
#
# [12 rows x 200 columns]
# <style type="text/css">
# </style>
# <table id="T_cf69c">
#   <caption>the column titles are the tags of the returned search results and their counts are in the cells below</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >topics</th>
#       <th id="T_cf69c_level0_col0" class="col_heading level0 col0" >assistive-technology</th>
#       <th id="T_cf69c_level0_col1" class="col_heading level0 col1" >screen-reader</th>
#       <th id="T_cf69c_level0_col2" class="col_heading level0 col2" >accessibility</th>
#       <th id="T_cf69c_level0_col3" class="col_heading level0 col3" >a11y</th>
#       <th id="T_cf69c_level0_col4" class="col_heading level0 col4" >wcag</th>
#       <th id="T_cf69c_level0_col5" class="col_heading level0 col5" >wai-aria</th>
#       <th id="T_cf69c_level0_col6" class="col_heading level0 col6" >nvda</th>
#       <th id="T_cf69c_level0_col7" class="col_heading level0 col7" >python</th>
#       <th id="T_cf69c_level0_col8" class="col_heading level0 col8" >text-to-speech</th>
#       <th id="T_cf69c_level0_col9" class="col_heading level0 col9" >ai</th>
#       <th id="T_cf69c_level0_col10" class="col_heading level0 col10" >openat</th>
#       <th id="T_cf69c_level0_col11" class="col_heading level0 col11" >aac</th>
#       <th id="T_cf69c_level0_col12" class="col_heading level0 col12" >aria</th>
#       <th id="T_cf69c_level0_col13" class="col_heading level0 col13" >machine-learning</th>
#       <th id="T_cf69c_level0_col14" class="col_heading level0 col14" >a11y-testing</th>
#       <th id="T_cf69c_level0_col15" class="col_heading level0 col15" >assistant</th>
#       <th id="T_cf69c_level0_col16" class="col_heading level0 col16" >voiceover</th>
#       <th id="T_cf69c_level0_col17" class="col_heading level0 col17" >a11y-automation</th>
#       <th id="T_cf69c_level0_col18" class="col_heading level0 col18" >voice-assistant</th>
#       <th id="T_cf69c_level0_col19" class="col_heading level0 col19" >javascript</th>
#       <th id="T_cf69c_level0_col20" class="col_heading level0 col20" >accessibility-testing</th>
#       <th id="T_cf69c_level0_col21" class="col_heading level0 col21" >screen-reader-api</th>
#       <th id="T_cf69c_level0_col22" class="col_heading level0 col22" >accessibility-automation</th>
#       <th id="T_cf69c_level0_col23" class="col_heading level0 col23" >python3</th>
#       <th id="T_cf69c_level0_col24" class="col_heading level0 col24" >mouse-emulation</th>
#       <th id="T_cf69c_level0_col25" class="col_heading level0 col25" >windows</th>
#       <th id="T_cf69c_level0_col26" class="col_heading level0 col26" >react</th>
#       <th id="T_cf69c_level0_col27" class="col_heading level0 col27" >tts</th>
#       <th id="T_cf69c_level0_col28" class="col_heading level0 col28" >open-source</th>
#       <th id="T_cf69c_level0_col29" class="col_heading level0 col29" >chrome-extension</th>
#       <th id="T_cf69c_level0_col30" class="col_heading level0 col30" >blind</th>
#       <th id="T_cf69c_level0_col31" class="col_heading level0 col31" >artificial-intelligence</th>
#       <th id="T_cf69c_level0_col32" class="col_heading level0 col32" >eye-tracking</th>
#       <th id="T_cf69c_level0_col33" class="col_heading level0 col33" >joystick</th>
#       <th id="T_cf69c_level0_col34" class="col_heading level0 col34" >web-accessibility</th>
#       <th id="T_cf69c_level0_col35" class="col_heading level0 col35" >inclusive-design</th>
#       <th id="T_cf69c_level0_col36" class="col_heading level0 col36" >a11y-api</th>
#       <th id="T_cf69c_level0_col37" class="col_heading level0 col37" >nvda-addon</th>
#       <th id="T_cf69c_level0_col38" class="col_heading level0 col38" >ocr</th>
#       <th id="T_cf69c_level0_col39" class="col_heading level0 col39" >arduino</th>
#       <th id="T_cf69c_level0_col40" class="col_heading level0 col40" >android</th>
#       <th id="T_cf69c_level0_col41" class="col_heading level0 col41" >firefox-extension</th>
#       <th id="T_cf69c_level0_col42" class="col_heading level0 col42" >asterics-main</th>
#       <th id="T_cf69c_level0_col43" class="col_heading level0 col43" >computer-vision</th>
#       <th id="T_cf69c_level0_col44" class="col_heading level0 col44" >human-computer-interaction</th>
#       <th id="T_cf69c_level0_col45" class="col_heading level0 col45" >robotics</th>
#       <th id="T_cf69c_level0_col46" class="col_heading level0 col46" >disability</th>
#       <th id="T_cf69c_level0_col47" class="col_heading level0 col47" >deep-learning</th>
#       <th id="T_cf69c_level0_col48" class="col_heading level0 col48" >mouth-mouse</th>
#       <th id="T_cf69c_level0_col49" class="col_heading level0 col49" >awesome</th>
#       <th id="T_cf69c_level0_col50" class="col_heading level0 col50" >linux</th>
#       <th id="T_cf69c_level0_col51" class="col_heading level0 col51" >voice-recognition</th>
#       <th id="T_cf69c_level0_col52" class="col_heading level0 col52" >screenreader</th>
#       <th id="T_cf69c_level0_col53" class="col_heading level0 col53" >opencv</th>
#       <th id="T_cf69c_level0_col54" class="col_heading level0 col54" >haskell</th>
#       <th id="T_cf69c_level0_col55" class="col_heading level0 col55" >typescript</th>
#       <th id="T_cf69c_level0_col56" class="col_heading level0 col56" >opera-extension</th>
#       <th id="T_cf69c_level0_col57" class="col_heading level0 col57" >html</th>
#       <th id="T_cf69c_level0_col58" class="col_heading level0 col58" >scala</th>
#       <th id="T_cf69c_level0_col59" class="col_heading level0 col59" >jaws</th>
#       <th id="T_cf69c_level0_col60" class="col_heading level0 col60" >speech-synthesis</th>
#       <th id="T_cf69c_level0_col61" class="col_heading level0 col61" >scalameta</th>
#       <th id="T_cf69c_level0_col62" class="col_heading level0 col62" >hardware</th>
#       <th id="T_cf69c_level0_col63" class="col_heading level0 col63" >neovim-plugin</th>
#       <th id="T_cf69c_level0_col64" class="col_heading level0 col64" >lip-mouse</th>
#       <th id="T_cf69c_level0_col65" class="col_heading level0 col65" >visually-impaired</th>
#       <th id="T_cf69c_level0_col66" class="col_heading level0 col66" >assistive</th>
#       <th id="T_cf69c_level0_col67" class="col_heading level0 col67" >keyboard-emulation</th>
#       <th id="T_cf69c_level0_col68" class="col_heading level0 col68" >vscode-extension</th>
#       <th id="T_cf69c_level0_col69" class="col_heading level0 col69" >cli</th>
#       <th id="T_cf69c_level0_col70" class="col_heading level0 col70" >youtube</th>
#       <th id="T_cf69c_level0_col71" class="col_heading level0 col71" >augmentative-and-alternative-communication</th>
#       <th id="T_cf69c_level0_col72" class="col_heading level0 col72" >cross-platform</th>
#       <th id="T_cf69c_level0_col73" class="col_heading level0 col73" >personal-assistant-framework</th>
#       <th id="T_cf69c_level0_col74" class="col_heading level0 col74" >keyboard</th>
#       <th id="T_cf69c_level0_col75" class="col_heading level0 col75" >documentation</th>
#       <th id="T_cf69c_level0_col76" class="col_heading level0 col76" >mouse</th>
#       <th id="T_cf69c_level0_col77" class="col_heading level0 col77" >personal-assistant</th>
#       <th id="T_cf69c_level0_col78" class="col_heading level0 col78" >gaming</th>
#       <th id="T_cf69c_level0_col79" class="col_heading level0 col79" >speech-to-code</th>
#       <th id="T_cf69c_level0_col80" class="col_heading level0 col80" >html5</th>
#       <th id="T_cf69c_level0_col81" class="col_heading level0 col81" >disabilities</th>
#       <th id="T_cf69c_level0_col82" class="col_heading level0 col82" >rust</th>
#       <th id="T_cf69c_level0_col83" class="col_heading level0 col83" >speech-recognition</th>
#       <th id="T_cf69c_level0_col84" class="col_heading level0 col84" >screenshot</th>
#       <th id="T_cf69c_level0_col85" class="col_heading level0 col85" >screen-capture</th>
#       <th id="T_cf69c_level0_col86" class="col_heading level0 col86" >eye-tracker</th>
#       <th id="T_cf69c_level0_col87" class="col_heading level0 col87" >assistant-chat-bots</th>
#       <th id="T_cf69c_level0_col88" class="col_heading level0 col88" >voice-programming
