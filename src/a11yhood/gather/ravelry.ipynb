# %% [markdown]
# # extracting accessibility related patterns from ravelry

# %% [markdown]
# %%
# ## bootstrap our search for accessible ravelry patterns
#
# there are several accessibility categories that need to be searched.
# they are captured in the `searches` mapping where the key is the name/index
# for the search and the value defines the query parameters.

# %%
with __import__("importnb").Notebook():
    from app import App
import os, time, random, operator
from toolz.curried import compose, do, partial
from pandas import Series

# %%
def get_search_cache(app):
    return (app.cache / "ravelry" / "search").client()
def get_pattern_cache(app):
    return (app.cache / "ravelry" / "patterns").client()

# %%
searches: dict = {
    "adaptive": {"pa": "adaptive"},
    "medical device access": {"pa": "medical-device-access"},
    "medical device support": {"pa": "medical-device-accessory"},
    # "mobility aid support": {"add": "mobility-aid-support"},
    # "other": {"add": "other-add-accessibility"},
    "therapy aid/toy": {"pa": "therapy-aid"},
    "medical": {"pc": "medical"}
}
@App.impl
def get_responses(app):
    auth = (os.environ["RAVELRY_USERNAME"], os.environ["RAVELRY_PASSWORD"])
    search_cache = get_search_cache(app)
    
    seed_urls = ("https://api.ravelry.com/patterns/search.json?" + Series(searches).apply(urllib.parse.urlencode))
    first_pages = seed_urls.apply(compose(do(print), search_cache.get), auth=auth)
    first_patterns = first_pages.apply(operator.methodcaller("json")).apply(Series)
    paginated = first_patterns.paginator.apply(Series)
    paginated = paginated[paginated.page_count.gt(1)].drop(columns="page")
    paginated = paginated.join(paginated.page_count.add(1).apply(compose(list, partial(range, 2))).explode().rename("page"))
    other_urls = seed_urls[paginated.index] + "&page=" + paginated.page.astype(str)
    other_urls.apply(compose(do(print), search_cache.get), auth=auth)
    get_pattern_requests(app, seed_urls, other_urls)

def get_pattern_requests(app, *df):
    search_cache = get_search_cache(app)
    patterns = (
        pandas.concat(df)
        .apply(search_cache.get)
        .apply(operator.methodcaller("json"))
        .apply(operator.itemgetter("patterns"))
        .explode()
        .apply(Series)
        .drop_duplicates("permalink")
    )
    pattern_urls = patterns.set_index(("https://www.ravelry.com/patterns/library/" + patterns["permalink"]).rename("url"))
    patterns = get_responses(app)
    pattern_chuck_size = 20
    pattern_urls = "https://api.ravelry.com/patterns.json?ids=" + (
        patterns.id.groupby(pandas.RangeIndex(len(patterns)) // pattern_chuck_size)
        .agg(list)
        .apply(compose("+".join, map(str)))
    )
    patterns_cache = get_pattern_cache(app)
    (
        pattern_urls.apply(compose(patterns_cache.get), auth=auth)
        .apply(operator.methodcaller("json"))
        .apply(operator.itemgetter("patterns"))
        .apply(compose(list, dict.values))
        .explode()
        .apply(Series)
    )
    
@App.impl
def get_frames(app):
    return (
        df := Series(get_search_cache(app).cache.responses)
        .apply(operator.methodcaller("json"))
        .apply(operator.itemgetter("patterns"))
        .explode()
        .apply(Series)
        .set_index("id")
    ).join(
        (
            g:= Series(get_pattern_cache(app).cache.responses)
            .apply(operator.methodcaller("json"))
            .apply(operator.itemgetter("patterns"))
            .apply(dict.values)
            .explode()
            .apply(Series)
            .set_index("id")
        )[g.columns.difference(df.columns)]
    )

# %%
if __name__ == "__main__":
    app = App()
    app.main(__import__(__name__), run=0 or locals().get("__file__") is not None)
    df = app.compact()
    display(
        df.T,
    )
# Out:
# id                                                                 1059854  \
# free                                                                  True
# name                                             Groovy Face Mask Lanyards
# permalink                                        groovy-face-mask-lanyards
# personal_attributes                                                   None
# first_photo              {'id': 96615983, 'sort_order': 1, 'user_id': 4...
# designer                 {'crochet_pattern_count': 5, 'favorites_count'...
# pattern_author           {'crochet_pattern_count': 5, 'favorites_count'...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                           2
# craft                    {'id': 1, 'name': 'Crochet', 'permalink': 'cro...
# created_at                                       2020/08/16 17:31:50 -0400
# currency                                                              None
# currency_symbol                                                       None
# difficulty_average                                                     0.0
# difficulty_count                                                       NaN
# download_location        {'type': 'ravelry', 'free': True, 'url': 'http...
# downloadable                                                          True
# favorites_count                                                         71
# gauge                                                                  3.0
# gauge_description                         3 stitches and 0.5 rows = 1 inch
# gauge_divisor                                                          1.0
# gauge_pattern
# generally_available                              2020/08/16 17:31:50 -0400
# has_uk_terminology                                                    None
# has_us_terminology                                                    True
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes                    **UPDATE**:  The entire staff of my school (K-...
# notes_html               \n<p><strong>UPDATE</strong>: The entire staff...
# packs                    [{'id': 92624481, 'primary_pack_id': None, 'pr...
# pattern_attributes       [{'id': 10, 'permalink': 'adult'}, {'id': 324,...
# pattern_categories       [{'id': 895, 'name': 'Other', 'permalink': 'ot...
# pattern_needle_sizes     [{'id': 9, 'us': '9.0', 'metric': 5.5, 'us_ste...
# pattern_type             {'clothing': False, 'id': 9, 'name': 'Other', ...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 96615983, 'sort_order': 1, 'user_id': ...
# price                                                                  NaN
# printings                [{'created_at': '2020/08/16 17:31:50 -0400', '...
# product_id                                                        632519.0
# projects_count                                                           5
# published                                                       2020/08/01
# queued_projects_count                                                    8
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                      True
# row_gauge                                                              0.5
# sizes_available                                                  free size
# unlisted_product_ids                                                  None
# updated_at                                       2020/08/22 16:03:24 -0400
# url
# volumes_in_library                                                    None
# yardage                                                               11.0
# yardage_description                                          11 - 12 yards
# yardage_max                                                           12.0
# yarn_list_type                                                         1.0
# yarn_weight              {'crochet_gauge': None, 'id': 12, 'knit_gauge'...
# yarn_weight_description                                    Worsted (9 wpi)
#
# id                                                                 1071789  \
# free                                                                 False
# name                                                       Knitt Ear Saver
# permalink                                                  knitt-ear-saver
# personal_attributes                                                   None
# first_photo              {'id': 97722032, 'sort_order': 1, 'user_id': 8...
# designer                 {'crochet_pattern_count': 5, 'favorites_count'...
# pattern_author           {'crochet_pattern_count': 5, 'favorites_count'...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                           0
# craft                    {'id': 1, 'name': 'Crochet', 'permalink': 'cro...
# created_at                                       2020/09/29 08:20:40 -0400
# currency                                                               EUR
# currency_symbol                                                          €
# difficulty_average                                                     0.0
# difficulty_count                                                       NaN
# download_location        {'type': 'ravelry', 'free': False, 'url': 'htt...
# downloadable                                                          True
# favorites_count                                                         12
# gauge                                                                 16.0
# gauge_description        16 stitches and 10 rows = 4 inches in double c...
# gauge_divisor                                                          4.0
# gauge_pattern                                               double crochet
# generally_available                              2020/09/29 08:20:40 -0400
# has_uk_terminology                                                    None
# has_us_terminology                                                    True
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes                    ·Knitt Ear Saver PATTERN·\r\n\r\nThe Knitt Ear...
# notes_html               \n<p>·Knitt Ear Saver PATTERN·</p>\n\n<p>The K...
# packs                    [{'id': 93472518, 'primary_pack_id': None, 'pr...
# pattern_attributes       [{'id': 3, 'permalink': 'unisex'}, {'id': 204,...
# pattern_categories       [{'id': 895, 'name': 'Other', 'permalink': 'ot...
# pattern_needle_sizes     [{'id': 6, 'us': '6.0', 'metric': 4.0, 'us_ste...
# pattern_type             {'clothing': False, 'id': 9, 'name': 'Other', ...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 97722032, 'sort_order': 1, 'user_id': ...
# price                                                                  1.0
# printings                [{'created_at': '2020/09/29 08:20:40 -0400', '...
# product_id                                                        642318.0
# projects_count                                                           1
# published                                                       2020/09/01
# queued_projects_count                                                    0
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                      True
# row_gauge                                                             10.0
# sizes_available                                                   one size
# unlisted_product_ids                                                  None
# updated_at                                       2020/09/29 16:35:07 -0400
# url                                         https://www.knitthandmade.com/
# volumes_in_library                                                    None
# yardage                                                                1.0
# yardage_description                                            1 - 3 yards
# yardage_max                                                            3.0
# yarn_list_type                                                         2.0
# yarn_weight              {'crochet_gauge': None, 'id': 10, 'knit_gauge'...
# yarn_weight_description                                     Sport (12 wpi)
#
# id                                                                 1091183  \
# free                                                                  True
# name                                             Completely Hooked Lanyard
# permalink                                        completely-hooked-lanyard
# personal_attributes                                                   None
# first_photo              {'id': 99416899, 'sort_order': 1, 'user_id': 1...
# designer                 {'crochet_pattern_count': 163, 'favorites_coun...
# pattern_author           {'crochet_pattern_count': 163, 'favorites_coun...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                           0
# craft                    {'id': 1, 'name': 'Crochet', 'permalink': 'cro...
# created_at                                       2020/11/30 17:27:32 -0500
# currency                                                               USD
# currency_symbol                                                          $
# difficulty_average                                                     0.0
# difficulty_count                                                       NaN
# download_location        {'type': 'external', 'free': True, 'url': 'htt...
# downloadable                                                          True
# favorites_count                                                        114
# gauge                                                                  1.0
# gauge_description                        1 stitches and 16 rows = 4 inches
# gauge_divisor                                                          4.0
# gauge_pattern
# generally_available                              2020/11/30 17:27:32 -0500
# has_uk_terminology                                                    True
# has_us_terminology                                                    True
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes                    *A PDF version of this pattern is emailed as p...
# notes_html               \n<p><em>A PDF version of this pattern is emai...
# packs                    [{'id': 94935083, 'primary_pack_id': None, 'pr...
# pattern_attributes       [{'id': 53, 'permalink': 'bobble-or-popcorn'},...
# pattern_categories       [{'id': 895, 'name': 'Other', 'permalink': 'ot...
# pattern_needle_sizes     [{'id': 4, 'us': '4.0', 'metric': 3.5, 'us_ste...
# pattern_type             {'clothing': False, 'id': 9, 'name': 'Other', ...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 99416899, 'sort_order': 1, 'user_id': ...
# price                                                                  NaN
# printings                [{'created_at': '2020/11/30 17:27:32 -0500', '...
# product_id                                                             NaN
# projects_count                                                           6
# published                                                       2020/11/01
# queued_projects_count                                                   13
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                     False
# row_gauge                                                             16.0
# sizes_available          One size (21"/53.34cm long) or your choice: ea...
# unlisted_product_ids                                                  None
# updated_at                                       2020/11/30 19:03:54 -0500
# url                      https://www.designingvashti.com/crochet-mask-l...
# volumes_in_library                                                    None
# yardage                                                                9.0
# yardage_description                                           9 - 11 yards
# yardage_max                                                           11.0
# yarn_list_type                                                         1.0
# yarn_weight              {'crochet_gauge': None, 'id': 11, 'knit_gauge'...
# yarn_weight_description                                        DK (11 wpi)
#
# id                                                                 1112262  \
# free                                                                  True
# name                                                    Stroke driver bags
# permalink                                               stroke-driver-bags
# personal_attributes                                                   None
# first_photo              {'id': 101641353, 'sort_order': 1, 'user_id': ...
# designer                 {'crochet_pattern_count': 1, 'favorites_count'...
# pattern_author           {'crochet_pattern_count': 1, 'favorites_count'...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                           0
# craft                    {'id': 2, 'name': 'Knitting', 'permalink': 'kn...
# created_at                                       2021/02/08 05:14:33 -0500
# currency                                                               USD
# currency_symbol                                                          $
# difficulty_average                                                     0.0
# difficulty_count                                                       NaN
# download_location        {'type': 'external', 'free': True, 'url': 'htt...
# downloadable                                                          True
# favorites_count                                                         13
# gauge                                                                  NaN
# gauge_description
# gauge_divisor                                                          4.0
# gauge_pattern
# generally_available                              2020/10/01 00:00:00 -0400
# has_uk_terminology                                                    None
# has_us_terminology                                                    None
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes
# notes_html
# packs                    [{'id': 96957517, 'primary_pack_id': None, 'pr...
# pattern_attributes       [{'id': 324, 'permalink': 'medical-device-acce...
# pattern_categories       [{'id': 888, 'name': 'Other', 'permalink': 'ot...
# pattern_needle_sizes     [{'id': 6, 'us': '6 ', 'metric': 4.0, 'us_stee...
# pattern_type             {'clothing': False, 'id': 15, 'name': 'Bag', '...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 101641353, 'sort_order': 1, 'user_id':...
# price                                                                  NaN
# printings                [{'created_at': '2021/02/08 05:14:33 -0500', '...
# product_id                                                             NaN
# projects_count                                                           0
# published                                                       2020/10/01
# queued_projects_count                                                    1
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                     False
# row_gauge                                                              NaN
# sizes_available                                                   one size
# unlisted_product_ids                                                  None
# updated_at                                       2021/02/08 05:24:05 -0500
# url                      https://handmadewithloveforpreemiesuk.blogspot...
# volumes_in_library                                                    None
# yardage                                                                NaN
# yardage_description                                                  yards
# yardage_max                                                            NaN
# yarn_list_type                                                         1.0
# yarn_weight              {'crochet_gauge': None, 'id': 11, 'knit_gauge'...
# yarn_weight_description                                        DK (11 wpi)
#
# id                                                                 1112336  \
# free                                                                  True
# name                                      Adaptive Adult Thumbless Mittens
# permalink                                 adaptive-adult-thumbless-mittens
# personal_attributes                                                   None
# first_photo              {'id': 101647374, 'sort_order': 1, 'user_id': ...
# designer                 {'crochet_pattern_count': 2, 'favorites_count'...
# pattern_author           {'crochet_pattern_count': 2, 'favorites_count'...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                           0
# craft                    {'id': 1, 'name': 'Crochet', 'permalink': 'cro...
# created_at                                       2021/02/08 09:51:37 -0500
# currency                                                              None
# currency_symbol                                                       None
# difficulty_average                                                     0.0
# difficulty_count                                                       NaN
# download_location        {'type': 'ravelry', 'free': True, 'url': 'http...
# downloadable                                                          True
# favorites_count                                                         29
# gauge                                                                  NaN
# gauge_description                                     Gauge doesn't matter
# gauge_divisor                                                          NaN
# gauge_pattern                                         Gauge doesn't matter
# generally_available                              2021/02/08 09:51:37 -0500
# has_uk_terminology                                                    None
# has_us_terminology                                                    True
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes                    These mittens were designed with the help of a...
# notes_html               \n<p>These mittens were designed with the help...
# packs                    [{'id': 96961673, 'primary_pack_id': None, 'pr...
# pattern_attributes       [{'id': 10, 'permalink': 'adult'}, {'id': 267,...
# pattern_categories       [{'id': 391, 'name': 'Mittens', 'permalink': '...
# pattern_needle_sizes     [{'id': 9, 'us': '9.0', 'metric': 5.5, 'us_ste...
# pattern_type             {'clothing': True, 'id': 8, 'name': 'Mittens/G...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 101647374, 'sort_order': 1, 'user_id':...
# price                                                                  NaN
# printings                [{'created_at': '2021/02/08 09:51:37 -0500', '...
# product_id                                                        675287.0
# projects_count                                                           1
# published                                                       2021/02/01
# queued_projects_count                                                    5
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                      True
# row_gauge                                                              NaN
# sizes_available                                                      Adult
# unlisted_product_ids                                                  None
# updated_at                                       2025/02/01 20:47:03 -0500
# url
# volumes_in_library                                                    None
# yardage                                                              150.0
# yardage_description                                        150 - 300 yards
# yardage_max                                                          300.0
# yarn_list_type                                                         1.0
# yarn_weight              {'crochet_gauge': None, 'id': 12, 'knit_gauge'...
# yarn_weight_description                                    Worsted (9 wpi)
#
# id                                                                 1112733  \
# free                                                                  True
# name                                      Bulky Adaptive Thumbless Mittens
# permalink                                 bulky-adaptive-thumbless-mittens
# personal_attributes                                                   None
# first_photo              {'id': 101684802, 'sort_order': 1, 'user_id': ...
# designer                 {'crochet_pattern_count': 2, 'favorites_count'...
# pattern_author           {'crochet_pattern_count': 2, 'favorites_count'...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                           0
# craft                    {'id': 1, 'name': 'Crochet', 'permalink': 'cro...
# created_at                                       2021/02/09 13:06:21 -0500
# currency                                                              None
# currency_symbol                                                       None
# difficulty_average                                                     0.0
# difficulty_count                                                       NaN
# download_location        {'type': 'ravelry', 'free': True, 'url': 'http...
# downloadable                                                          True
# favorites_count                                                         16
# gauge                                                                  NaN
# gauge_description                                     Gauge doesn't matter
# gauge_divisor                                                          4.0
# gauge_pattern                                         Gauge doesn't matter
# generally_available                              2021/02/09 13:06:21 -0500
# has_uk_terminology                                                    None
# has_us_terminology                                                    True
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes                    This is the bulky yarn version of my previous ...
# notes_html               \n<p>This is the bulky yarn version of my prev...
# packs                    [{'id': 129012669, 'primary_pack_id': None, 'p...
# pattern_attributes       [{'id': 3, 'permalink': 'unisex'}, {'id': 10, ...
# pattern_categories       [{'id': 391, 'name': 'Mittens', 'permalink': '...
# pattern_needle_sizes     [{'id': 12, 'us': '11.0', 'metric': 8.0, 'us_s...
# pattern_type             {'clothing': True, 'id': 8, 'name': 'Mittens/G...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 101684802, 'sort_order': 1, 'user_id':...
# price                                                                  NaN
# printings                [{'created_at': '2021/02/09 13:06:21 -0500', '...
# product_id                                                        675675.0
# projects_count                                                           0
# published                                                       2021/02/01
# queued_projects_count                                                    0
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                      True
# row_gauge                                                              NaN
# sizes_available                                                      Adult
# unlisted_product_ids                                                  None
# updated_at                                       2025/02/01 20:47:38 -0500
# url
# volumes_in_library                                                    None
# yardage                                                              100.0
# yardage_description                                        100 - 150 yards
# yardage_max                                                          150.0
# yarn_list_type                                                         1.0
# yarn_weight              {'crochet_gauge': '', 'id': 4, 'knit_gauge': '...
# yarn_weight_description                                      Bulky (7 wpi)
#
# id                                                                 1119218  \
# free                                                                 False
# name                                     Variety Ear Savers for Face Masks
# permalink                                variety-ear-savers-for-face-masks
# personal_attributes                                                   None
# first_photo              {'id': 102277277, 'sort_order': 1, 'user_id': ...
# designer                 {'crochet_pattern_count': 4, 'favorites_count'...
# pattern_author           {'crochet_pattern_count': 4, 'favorites_count'...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                           0
# craft                    {'id': 1, 'name': 'Crochet', 'permalink': 'cro...
# created_at                                       2021/02/28 14:17:01 -0500
# currency                                                               USD
# currency_symbol                                                          $
# difficulty_average                                                     0.0
# difficulty_count                                                       NaN
# download_location        {'type': 'ravelry', 'free': False, 'url': 'htt...
# downloadable                                                          True
# favorites_count                                                         21
# gauge                                                                  NaN
# gauge_description
# gauge_divisor                                                          4.0
# gauge_pattern
# generally_available                              2021/02/28 14:17:01 -0500
# has_uk_terminology                                                    None
# has_us_terminology                                                    True
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes                    Stay safe and save your ears with these cute c...
# notes_html               \n<p>Stay safe and save your ears with these c...
# packs                    [{'id': 97519678, 'primary_pack_id': None, 'pr...
# pattern_attributes       [{'id': 205, 'permalink': 'seamless'}, {'id': ...
# pattern_categories       [{'id': 895, 'name': 'Other', 'permalink': 'ot...
# pattern_needle_sizes                                                    []
# pattern_type             {'clothing': False, 'id': 9, 'name': 'Other', ...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 102277277, 'sort_order': 1, 'user_id':...
# price                                                                  1.5
# printings                [{'created_at': '2021/02/28 14:17:02 -0500', '...
# product_id                                                        681039.0
# projects_count                                                           0
# published                                                       2021/02/01
# queued_projects_count                                                    2
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                      True
# row_gauge                                                              NaN
# sizes_available                                                  All sizes
# unlisted_product_ids                                                  None
# updated_at                                       2024/05/08 03:02:31 -0400
# url
# volumes_in_library                                                    None
# yardage                                                                NaN
# yardage_description                                                  yards
# yardage_max                                                            NaN
# yarn_list_type                                                         1.0
# yarn_weight              {'crochet_gauge': None, 'id': 15, 'knit_gauge'...
# yarn_weight_description                 Any gauge - designed for any gauge
#
# id                                                                 1130885  \
# free                                                                  True
# name                                        Mio's Mask Extender Ear Savers
# permalink                                    mios-mask-extender-ear-savers
# personal_attributes                                                   None
# first_photo              {'id': 103365201, 'sort_order': 1, 'user_id': ...
# designer                 {'crochet_pattern_count': 0, 'favorites_count'...
# pattern_author           {'crochet_pattern_count': 0, 'favorites_count'...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                          13
# craft                    {'id': 2, 'name': 'Knitting', 'permalink': 'kn...
# created_at                                       2021/04/09 11:46:27 -0400
# currency                                                              None
# currency_symbol                                                       None
# difficulty_average                                                     3.0
# difficulty_count                                                       3.0
# download_location        {'type': 'ravelry', 'free': True, 'url': 'http...
# downloadable                                                          True
# favorites_count                                                        305
# gauge                                                                  NaN
# gauge_description
# gauge_divisor                                                          4.0
# gauge_pattern
# generally_available                              2021/04/09 11:46:27 -0400
# has_uk_terminology                                                    None
# has_us_terminology                                                    None
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes                    Designed for my kindergartener who just return...
# notes_html               \n<p>Designed for my kindergartener who just r...
# packs                    [{'id': 98408229, 'primary_pack_id': None, 'pr...
# pattern_attributes       [{'id': 324, 'permalink': 'medical-device-acce...
# pattern_categories       [{'id': 895, 'name': 'Other', 'permalink': 'ot...
# pattern_needle_sizes     [{'id': 1, 'us': '1 ', 'metric': 2.25, 'us_ste...
# pattern_type             {'clothing': False, 'id': 9, 'name': 'Other', ...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 103365201, 'sort_order': 1, 'user_id':...
# price                                                                  NaN
# printings                [{'created_at': '2021/04/09 11:46:27 -0400', '...
# product_id                                                        690206.0
# projects_count                                                           8
# published                                                       2021/04/01
# queued_projects_count                                                   31
# rating_average                                                    4.666667
# rating_count                                                           3.0
# ravelry_download                                                      True
# row_gauge                                                              NaN
# sizes_available                                                     3-6 in
# unlisted_product_ids                                                  None
# updated_at                                       2021/04/09 18:54:02 -0400
# url
# volumes_in_library                                                    None
# yardage                                                               15.0
# yardage_description                                          15 - 20 yards
# yardage_max                                                           20.0
# yarn_list_type                                                         1.0
# yarn_weight              {'crochet_gauge': None, 'id': 11, 'knit_gauge'...
# yarn_weight_description                                        DK (11 wpi)
#
# id                                                                 1183021  \
# free                                                                 False
# name                                                 Too Hot To Handle Bag
# permalink                                            too-hot-to-handle-bag
# personal_attributes                                                   None
# first_photo              {'id': 107623644, 'sort_order': 1, 'user_id': ...
# designer                 {'crochet_pattern_count': 7, 'favorites_count'...
# pattern_author           {'crochet_pattern_count': 7, 'favorites_count'...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                           0
# craft                    {'id': 1, 'name': 'Crochet', 'permalink': 'cro...
# created_at                                       2021/10/17 15:04:18 -0400
# currency                                                               USD
# currency_symbol                                                          $
# difficulty_average                                                     0.0
# difficulty_count                                                       NaN
# download_location                                                     None
# downloadable                                                         False
# favorites_count                                                          8
# gauge                                                                 22.0
# gauge_description        22 stitches and 25 rows = 4 inches in Single C...
# gauge_divisor                                                          4.0
# gauge_pattern                                               Single Crochet
# generally_available                              2021/10/17 15:04:18 -0400
# has_uk_terminology                                                    None
# has_us_terminology                                                    True
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes                    This pattern is no longer available for purchase.
# notes_html               \n<p>This pattern is no longer available for p...
# packs                    [{'id': 102155629, 'primary_pack_id': None, 'p...
# pattern_attributes       [{'id': 62, 'permalink': 'lace'}, {'id': 89, '...
# pattern_categories       [{'id': 375, 'name': 'Purse / Handbag', 'perma...
# pattern_needle_sizes     [{'id': 5, 'us': '5.0', 'metric': 3.75, 'us_st...
# pattern_type             {'clothing': False, 'id': 15, 'name': 'Bag', '...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 107623644, 'sort_order': 1, 'user_id':...
# price                                                                  NaN
# printings                [{'created_at': '2021/10/17 15:04:18 -0400', '...
# product_id                                                             NaN
# projects_count                                                           0
# published                                                       2021/10/01
# queued_projects_count                                                    0
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                     False
# row_gauge                                                             25.0
# sizes_available                                                   One Size
# unlisted_product_ids                                                  None
# updated_at                                       2025/03/31 14:06:59 -0400
# url
# volumes_in_library                                                    None
# yardage                                                              450.0
# yardage_description                                        450 - 520 yards
# yardage_max                                                          520.0
# yarn_list_type                                                         1.0
# yarn_weight              {'crochet_gauge': '', 'id': 1, 'knit_gauge': '...
# yarn_weight_description                                       Aran (8 wpi)
#
# id                                                                 1208154  \
# free                                                                  True
# name                                                  Chemo Strap & Holder
# permalink                                              chemo-strap--holder
# personal_attributes                                                   None
# first_photo              {'id': 109859573, 'sort_order': 1, 'user_id': ...
# designer                 {'crochet_pattern_count': 1, 'favorites_count'...
# pattern_author           {'crochet_pattern_count': 1, 'favorites_count'...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                           0
# craft                    {'id': 1, 'name': 'Crochet', 'permalink': 'cro...
# created_at                                       2022/01/13 18:15:07 -0500
# currency                                                              None
# currency_symbol                                                       None
# difficulty_average                                                     0.0
# difficulty_count                                                       NaN
# download_location        {'type': 'ravelry', 'free': True, 'url': 'http...
# downloadable                                                          True
# favorites_count                                                         21
# gauge                                                                  4.0
# gauge_description        4 stitches and 4 rows = 4 inches in Four rows ...
# gauge_divisor                                                          4.0
# gauge_pattern                                        Four rows of 16 sc st
# generally_available                              2021/12/01 00:00:00 -0500
# has_uk_terminology                                                    None
# has_us_terminology                                                    True
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes                    Pattern is for a cross-body strap and a holder...
# notes_html               \n<p>Pattern is for a cross-body strap and a h...
# packs                    [{'id': 107061735, 'primary_pack_id': None, 'p...
# pattern_attributes       [{'id': 324, 'permalink': 'medical-device-acce...
# pattern_categories       [{'id': 888, 'name': 'Other', 'permalink': 'ot...
# pattern_needle_sizes     [{'id': 7, 'us': '7.0', 'metric': 4.5, 'us_ste...
# pattern_type             {'clothing': False, 'id': 15, 'name': 'Bag', '...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 109859573, 'sort_order': 1, 'user_id':...
# price                                                                  NaN
# printings                [{'created_at': '2022/01/13 18:15:07 -0500', '...
# product_id                                                        750941.0
# projects_count                                                           0
# published                                                       2021/12/01
# queued_projects_count                                                    2
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                      True
# row_gauge                                                              4.0
# sizes_available                                                See pattern
# unlisted_product_ids                                                  None
# updated_at                                       2022/06/01 05:31:38 -0400
# url
# volumes_in_library                                                    None
# yardage                                                              300.0
# yardage_description                                        300 - 400 yards
# yardage_max                                                          400.0
# yarn_list_type                                                         1.0
# yarn_weight              {'crochet_gauge': '', 'id': 4, 'knit_gauge': '...
# yarn_weight_description                                      Bulky (7 wpi)
#
# id                       ...  \
# free                     ...
# name                     ...
# permalink                ...
# personal_attributes      ...
# first_photo              ...
# designer                 ...
# pattern_author           ...
# pattern_sources          ...
# comments_count           ...
# craft                    ...
# created_at               ...
# currency                 ...
# currency_symbol          ...
# difficulty_average       ...
# difficulty_count         ...
# download_location        ...
# downloadable             ...
# favorites_count          ...
# gauge                    ...
# gauge_description        ...
# gauge_divisor            ...
# gauge_pattern            ...
# generally_available      ...
# has_uk_terminology       ...
# has_us_terminology       ...
# languages                ...
# notes                    ...
# notes_html               ...
# packs                    ...
# pattern_attributes       ...
# pattern_categories       ...
# pattern_needle_sizes     ...
# pattern_type             ...
# pdf_in_library           ...
# pdf_url                  ...
# photos                   ...
# price                    ...
# printings                ...
# product_id               ...
# projects_count           ...
# published                ...
# queued_projects_count    ...
# rating_average           ...
# rating_count             ...
# ravelry_download         ...
# row_gauge                ...
# sizes_available          ...
# unlisted_product_ids     ...
# updated_at               ...
# url                      ...
# volumes_in_library       ...
# yardage                  ...
# yardage_description      ...
# yardage_max              ...
# yarn_list_type           ...
# yarn_weight              ...
# yarn_weight_description  ...
#
# id                                                                 982660   \
# free                                                                  True
# name                                                           Knit Packer
# permalink                                                      knit-packer
# personal_attributes                                                   None
# first_photo              {'id': 89220179, 'sort_order': 1, 'user_id': 1...
# designer                 {'crochet_pattern_count': 0, 'favorites_count'...
# pattern_author           {'crochet_pattern_count': 0, 'favorites_count'...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                          24
# craft                    {'id': 2, 'name': 'Knitting', 'permalink': 'kn...
# ...
# notes                    [Please note, this is not a physical product, ...
# notes_html               \n<p><span>Please note, this is not a physical...
# packs                    [{'id': 86789101, 'primary_pack_id': None, 'pr...
# pattern_attributes       [{'id': 86, 'permalink': 'seamed'}, {'id': 247...
# pattern_categories       [{'id': 553, 'name': 'Mature Content', 'permal...
# pattern_needle_sizes                                                    []
# pattern_type             {'clothing': False, 'id': 16, 'name': 'Toys', ...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 90355998, 'sort_order': 1, 'user_id': ...
# price                                                                  5.0
# printings                [{'created_at': '2022/09/06 13:23:10 -0400', '...
# product_id                                                             NaN
# projects_count                                                           1
# published                                                       2020/01/01
# queued_projects_count                                                    1
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                     False
# row_gauge                                                              NaN
# sizes_available
# unlisted_product_ids                                                  None
# updated_at                                       2022/09/06 13:23:10 -0400
# url                      https://guelphmarket.com/products/crochet-soft...
# volumes_in_library                                                    None
# yardage                                                                NaN
# yardage_description                                                  yards
# yardage_max                                                            NaN
# yarn_list_type                                                         1.0
# yarn_weight                                                            NaN
# yarn_weight_description                                               None
#
# id                                                                 1004598  \
# free                                                                  True
# name                                                  Chill Buddy Ice Pack
# permalink                                             chill-buddy-ice-pack
# personal_attributes                                                   None
# first_photo              {'id': 91502062, 'sort_order': 1, 'user_id': 2...
# designer                 {'crochet_pattern_count': 1013, 'favorites_cou...
# pattern_author           {'crochet_pattern_count': 1013, 'favorites_cou...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                           0
# craft                    {'id': 1, 'name': 'Crochet', 'permalink': 'cro...
# created_at                                       2020/02/13 13:20:53 -0500
# currency                                                               USD
# currency_symbol                                                          $
# difficulty_average                                                     0.0
# difficulty_count                                                       NaN
# download_location        {'type': 'ravelry', 'free': False, 'url': 'htt...
# downloadable                                                          True
# favorites_count                                                        172
# gauge                                                                  NaN
# gauge_description
# gauge_divisor                                                          4.0
# gauge_pattern
# generally_available                              2020/01/01 00:00:00 -0500
# has_uk_terminology                                                    None
# has_us_terminology                                                    True
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes                    This pattern is available for [free on my blog...
# notes_html               \n<p>This pattern is available for <a href="ht...
# packs                    [{'id': 87930454, 'primary_pack_id': None, 'pr...
# pattern_attributes       [{'id': 267, 'permalink': 'written-pattern'}, ...
# pattern_categories       [{'id': 440, 'name': 'Medical', 'permalink': '...
# pattern_needle_sizes     [{'id': 8, 'us': '8.0', 'metric': 5.0, 'us_ste...
# pattern_type             {'clothing': False, 'id': 21, 'name': 'Home', ...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 91502062, 'sort_order': 1, 'user_id': ...
# price                                                                  3.0
# printings                [{'created_at': '2020/02/13 13:20:53 -0500', '...
# product_id                                                        588592.0
# projects_count                                                           3
# published                                                       2020/01/01
# queued_projects_count                                                   15
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                      True
# row_gauge                                                              NaN
# sizes_available
# unlisted_product_ids                                                  None
# updated_at                                       2024/01/22 11:26:50 -0500
# url                      https://snappy-tots.com/wednesday-wash-3-chill...
# volumes_in_library                                                    None
# yardage                                                              100.0
# yardage_description                                        100 - 125 yards
# yardage_max                                                          125.0
# yarn_list_type                                                         1.0
# yarn_weight              {'crochet_gauge': None, 'id': 12, 'knit_gauge'...
# yarn_weight_description                                    Worsted (9 wpi)
#
# id                                                                 1006146  \
# free                                                                 False
# name                                                 I Love You in Braille
# permalink                                            i-love-you-in-braille
# personal_attributes                                                   None
# first_photo              {'id': 91654487, 'sort_order': 1, 'user_id': 1...
# designer                 {'crochet_pattern_count': 1, 'favorites_count'...
# pattern_author           {'crochet_pattern_count': 1, 'favorites_count'...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                           0
# craft                    {'id': 1, 'name': 'Crochet', 'permalink': 'cro...
# created_at                                       2020/02/18 23:11:22 -0500
# currency                                                               USD
# currency_symbol                                                          $
# difficulty_average                                                     0.0
# difficulty_count                                                       NaN
# download_location        {'type': 'ravelry', 'free': False, 'url': 'htt...
# downloadable                                                          True
# favorites_count                                                         30
# gauge                                                                 15.0
# gauge_description         15 stitches and 12 rows = 4 inches in HDC or HTR
# gauge_divisor                                                          4.0
# gauge_pattern                                                   HDC or HTR
# generally_available                              2020/02/18 23:11:22 -0500
# has_uk_terminology                                                    True
# has_us_terminology                                                    True
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes                    When I was small I watched a gentleman reading...
# notes_html               \n<p>When I was small I watched a gentleman re...
# packs                    [{'id': 88078858, 'primary_pack_id': None, 'pr...
# pattern_attributes       [{'id': 53, 'permalink': 'bobble-or-popcorn'},...
# pattern_categories       [{'id': 482, 'name': 'Washcloth / Dishcloth', ...
# pattern_needle_sizes     [{'id': 8, 'us': '8.0', 'metric': 5.0, 'us_ste...
# pattern_type             {'clothing': False, 'id': 24, 'name': 'Dishclo...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 91654487, 'sort_order': 1, 'user_id': ...
# price                                                                  2.0
# printings                [{'created_at': '2021/03/29 22:09:35 -0400', '...
# product_id                                                        589750.0
# projects_count                                                           7
# published                                                       2020/02/01
# queued_projects_count                                                    0
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                      True
# row_gauge                                                             12.0
# sizes_available          20cm (8”) wide x 21cm (8 ¼”) long (easily adju...
# unlisted_product_ids                                                  None
# updated_at                                       2022/01/10 20:50:01 -0500
# url
# volumes_in_library                                                    None
# yardage                                                               79.0
# yardage_description                                               79 yards
# yardage_max                                                            NaN
# yarn_list_type                                                         1.0
# yarn_weight              {'crochet_gauge': '', 'id': 1, 'knit_gauge': '...
# yarn_weight_description                                       Aran (8 wpi)
#
# id                                                                 1007543
# free                                                                 False
# name                                  I Love You in Braille Knit Washcloth
# permalink                             i-love-you-in-braille-knit-washcloth
# personal_attributes                                                   None
# first_photo              {'id': 91791547, 'sort_order': 1, 'user_id': 1...
# designer                 {'crochet_pattern_count': 1, 'favorites_count'...
# pattern_author           {'crochet_pattern_count': 1, 'favorites_count'...
# pattern_sources          [{'amazon_rating': None, 'amazon_reviews': Non...
# comments_count                                                           2
# craft                    {'id': 2, 'name': 'Knitting', 'permalink': 'kn...
# created_at                                       2020/02/23 22:23:59 -0500
# currency                                                               USD
# currency_symbol                                                          $
# difficulty_average                                                     0.0
# difficulty_count                                                       NaN
# download_location        {'type': 'ravelry', 'free': False, 'url': 'htt...
# downloadable                                                          True
# favorites_count                                                         57
# gauge                                                                 20.0
# gauge_description        20 stitches and 28 rows = 4 inches in Stockinette
# gauge_divisor                                                          4.0
# gauge_pattern                                                  Stockinette
# generally_available                              2020/02/23 22:23:59 -0500
# has_uk_terminology                                                    None
# has_us_terminology                                                    None
# languages                [{'code': 'en', 'id': 1, 'name': 'English', 'p...
# notes                    When I was small I watched a gentleman reading...
# notes_html               \n<p>When I was small I watched a gentleman re...
# packs                    [{'id': 88212134, 'primary_pack_id': None, 'pr...
# pattern_attributes       [{'id': 53, 'permalink': 'bobble-or-popcorn'},...
# pattern_categories       [{'id': 482, 'name': 'Washcloth / Dishcloth', ...
# pattern_needle_sizes     [{'id': 6, 'us': '6 ', 'metric': 4.0, 'us_stee...
# pattern_type             {'clothing': False, 'id': 24, 'name': 'Dishclo...
# pdf_in_library                                                       False
# pdf_url
# photos                   [{'id': 91791547, 'sort_order': 1, 'user_id': ...
# price                                                                  2.0
# printings                [{'created_at': '2021/03/28 08:14:42 -0400', '...
# product_id                                                        590831.0
# projects_count                                                           2
# published                                                       2020/02/01
# queued_projects_count                                                    4
# rating_average                                                         0.0
# rating_count                                                           NaN
# ravelry_download                                                      True
# row_gauge                                                             28.0
# sizes_available                        19.5cm (7¾ ”) wide x 20cm (8”) high
# unlisted_product_ids                                                  None
# updated_at                                       2022/12/08 21:35:41 -0500
# url
# volumes_in_library                                                    None
# yardage                                                               49.0
# yardage_description                                               49 yards
# yardage_max                                                            NaN
# yarn_list_type                                                         1.0
# yarn_weight              {'crochet_gauge': '', 'id': 1, 'knit_gauge': '...
# yarn_weight_description                                       Aran (8 wpi)
#
# [57 rows x 690 columns]
